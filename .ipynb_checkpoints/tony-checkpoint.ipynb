# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
from matplotlib import pyplot
plt.style.use('fivethirtyeight')

pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv("combined_energy_data.csv", low_memory=False)

# %%
df['datetime'] = df['datetime'].apply(lambda x: x.split("+")[0])

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df = df[df.Consumption.notnull()]

# %%
ac_df = pd.read_csv("energy-ile-de-france.txt", sep=',',header = None,names=['timestamp','wind'])

# %%
ac_df['datetime'] = pd.to_datetime(ac_df['timestamp'],unit='ms')

# %%
df.columns
# Out:
# Index(['Perimeter', 'Nature', 'Dated', 'Hours', 'Consumption', 'Forecast D-1',
#        'Forecast J', 'Fuel oil', 'Coal', 'Gas', 'Nuclear', 'Wind', 'Solar',
#        'Hydraulic', 'Pumping', 'Bioenergies', 'Ech. physical', 'Co2 rate',
#        'Ech. comm. England', 'Ech. comm. Spain', 'Ech. comm. Italy',
#        'Ech. comm. Swiss', 'Ech. comm. Germany-Belgium', 'Fuel oil - TAC',
#        'Fuel oil - Cogen.', 'Fuel oil - Others', 'Gas - TAC', 'Gas - Cogen.',
#        'Gas - CCG', 'Gas - Others', 'Hydraulic - Stream of water + lock',
#        'Hydraulics - Lakes', 'Hydraulics - STEP turbines',
#        'Bioenergies - Waste', 'Bioenergies - Biomass', 'Bioenergies - Biogas',
#        'datetime', 'guitrancourt_Speed(m/s)', 'guitrancourt_Direction (deg N)',
#        'lieusaint_Speed(m/s)', 'lieusaint_Direction (deg N)',
#        'lvs-pussay_Speed(m/s)', 'lvs-pussay_Direction (deg N)',
#        'parc-du-gatinais_Speed(m/s)', 'parc-du-gatinais_Direction (deg N)',
#        'arville_Speed(m/s)', 'arville_Direction (deg N)',
#        'boissy-la-riviere_Speed(m/s)', 'boissy-la-riviere_Direction (deg N)',
#        'angerville-1_Speed(m/s)', 'angerville-1_Direction (deg N)',
#        'angerville-2_Speed(m/s)', 'angerville-2_Direction (deg N)',
#        'guitrancourt-b_Speed(m/s)', 'guitrancourt-b_Direction (deg N)',
#        'lieusaint-b_Speed(m/s)', 'lieusaint-b_Direction (deg N)',
#        'lvs-pussay-b_Speed(m/s)', 'lvs-pussay-b_Direction (deg N)',
#        'parc-du-gatinais-b_Speed(m/s)', 'parc-du-gatinais-b_Direction (deg N)',
#        'arville-b_Speed(m/s)', 'arville-b_Direction (deg N)',
#        'boissy-la-riviere-b_Speed(m/s)',
#        'boissy-la-riviere-b_Direction (deg N)', 'angerville-1-b_Speed(m/s)',
#        'angerville-1-b_Direction (deg N)', 'angerville-2-b_Speed(m/s)',
#        'angerville-2-b_Direction (deg N)'],
#       dtype='object')

# %%
df[df['guitrancourt_Speed(m/s)'].notnull()].head(500)[['Wind','guitrancourt_Speed(m/s)', 'guitrancourt_Direction (deg N)']].astype(float).plot(style=['r','b','y'],figsize=(20,20))

# %%
columns_use = ['datetime', 'guitrancourt_Speed(m/s)', 'guitrancourt_Direction (deg N)',
       'lieusaint_Speed(m/s)', 'lieusaint_Direction (deg N)',
       'lvs-pussay_Speed(m/s)', 'lvs-pussay_Direction (deg N)',
       'parc-du-gatinais_Speed(m/s)', 'parc-du-gatinais_Direction (deg N)',
       'arville_Speed(m/s)', 'arville_Direction (deg N)',
       'boissy-la-riviere_Speed(m/s)', 'boissy-la-riviere_Direction (deg N)',
       'angerville-1_Speed(m/s)', 'angerville-1_Direction (deg N)',
       'angerville-2_Speed(m/s)', 'angerville-2_Direction (deg N)',
       'guitrancourt-b_Speed(m/s)', 'guitrancourt-b_Direction (deg N)',
       'lieusaint-b_Speed(m/s)', 'lieusaint-b_Direction (deg N)',
       'lvs-pussay-b_Speed(m/s)', 'lvs-pussay-b_Direction (deg N)',
       'parc-du-gatinais-b_Speed(m/s)', 'parc-du-gatinais-b_Direction (deg N)',
       'arville-b_Speed(m/s)', 'arville-b_Direction (deg N)',
       'boissy-la-riviere-b_Speed(m/s)',
       'boissy-la-riviere-b_Direction (deg N)', 'angerville-1-b_Speed(m/s)',
       'angerville-1-b_Direction (deg N)', 'angerville-2-b_Speed(m/s)',
       'angerville-2-b_Direction (deg N)']

# %%
agg_df = df[['datetime','Wind']].groupby([df['datetime'].dt.floor('H')]).agg(['mean','sum','std'])

# %%
agg_df.columns = agg_df.columns.map('_'.join)

# %%
agg_df = agg_df.reset_index()

# %%
merge_df = agg_df.merge(df[columns_use], how='left', on='datetime')

# %%
df
# Out:
#        Perimeter               Nature       Dated  Hours  Consumption  \
# 0         France  Données définitives  2017-01-01  00:00      76259.0
# 2         France  Données définitives  2017-01-01  00:30      74981.0
# 4         France  Données définitives  2017-01-01  01:00      72912.0
# 6         France  Données définitives  2017-01-01  01:30      72682.0
# 8         France  Données définitives  2017-01-01  02:00      72166.0
# ...          ...                  ...         ...    ...          ...
# 124069    France   Données temps réel  2020-07-16  09:15      49066.0
# 124070    France   Données temps réel  2020-07-16  09:30      49297.0
# 124071    France   Données temps réel  2020-07-16  09:45      49530.0
# 124072    France   Données temps réel  2020-07-16  10:00      49923.0
# 124073    France   Données temps réel  2020-07-16  10:15      50407.0
#
#        Forecast D-1 Forecast J  Fuel oil    Coal     Gas  ...  \
# 0           76100.0    76500.0     164.0  1579.0  7617.0  ...
# 2           74900.0    75100.0     601.0  1506.0  6626.0  ...
# 4           73400.0    73400.0     596.0  1291.0  6593.0  ...
# 6           73900.0    73900.0     587.0  1028.0  6595.0  ...
# 8           73300.0    73300.0     599.0  1024.0  6548.0  ...
# ...             ...        ...       ...     ...     ...  ...
# 124069        49400      49300     140.0   591.0  4167.0  ...
# 124070        49800      49700     139.0   592.0  4174.0  ...
# 124071        50150      50050     140.0   592.0  4210.0  ...
# 124072        50500      50400     140.0   591.0  4140.0  ...
# 124073        50700      50600     140.0   590.0  4145.0  ...
#
#         parc-du-gatinais-b_Speed(m/s)  parc-du-gatinais-b_Direction (deg N)  \
# 0                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 4                                2.51                                 225.0
# 6                                 NaN                                   NaN
# 8                                 NaN                                   NaN
# ...                               ...                                   ...
# 124069                            NaN                                   NaN
# 124070                            NaN                                   NaN
# 124071                            NaN                                   NaN
# 124072                            NaN                                   NaN
# 124073                            NaN                                   NaN
#
#         arville-b_Speed(m/s)  arville-b_Direction (deg N)  \
# 0                        NaN                          NaN
# 2                        NaN                          NaN
# 4                       2.52                        225.0
# 6                        NaN                          NaN
# 8                        NaN                          NaN
# ...                      ...                          ...
# 124069                   NaN                          NaN
# 124070                   NaN                          NaN
# 124071                   NaN                          NaN
# 124072                   NaN                          NaN
# 124073                   NaN                          NaN
#
#         boissy-la-riviere-b_Speed(m/s)  boissy-la-riviere-b_Direction (deg N)  \
# 0                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 4                                 2.73                                  226.0
# 6                                  NaN                                    NaN
# 8                                  NaN                                    NaN
# ...                                ...                                    ...
# 124069                             NaN                                    NaN
# 124070                             NaN                                    NaN
# 124071                             NaN                                    NaN
# 124072                             NaN                                    NaN
# 124073                             NaN                                    NaN
#
#         angerville-1-b_Speed(m/s)  angerville-1-b_Direction (deg N)  \
# 0                             NaN                               NaN
# 2                             NaN                               NaN
# 4                            2.74                             228.0
# 6                             NaN                               NaN
# 8                             NaN                               NaN
# ...                           ...                               ...
# 124069                        NaN                               NaN
# 124070                        NaN                               NaN
# 124071                        NaN                               NaN
# 124072                        NaN                               NaN
# 124073                        NaN                               NaN
#
#         angerville-2-b_Speed(m/s)  angerville-2-b_Direction (deg N)
# 0                             NaN                               NaN
# 2                             NaN                               NaN
# 4                            2.74                             228.0
# 6                             NaN                               NaN
# 8                             NaN                               NaN
# ...                           ...                               ...
# 124069                        NaN                               NaN
# 124070                        NaN                               NaN
# 124071                        NaN                               NaN
# 124072                        NaN                               NaN
# 124073                        NaN                               NaN
#
# [64218 rows x 69 columns]

# %%
merge_df
# Out:
#                  datetime  Wind_mean  Wind_sum   Wind_std  \
# 0     2016-12-31 23:00:00     289.00     578.0  31.112698
# 1     2017-01-01 00:00:00     359.00     718.0  11.313708
# 2     2017-01-01 01:00:00     357.00     714.0   4.242641
# 3     2017-01-01 02:00:00     340.50     681.0   0.707107
# 4     2017-01-01 03:00:00     384.00     768.0  11.313708
# ...                   ...        ...       ...        ...
# 31014 2020-07-16 04:00:00    1472.75    5891.0  45.220755
# 31015 2020-07-16 05:00:00    1489.25    5957.0  35.864328
# 31016 2020-07-16 06:00:00    1440.50    5762.0  20.760539
# 31017 2020-07-16 07:00:00    1495.50    5982.0  65.612499
# 31018 2020-07-16 08:00:00    1610.00    3220.0  32.526912
#
#        guitrancourt_Speed(m/s)  guitrancourt_Direction (deg N)  \
# 0                          NaN                             NaN
# 1                         1.86                           212.0
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
# ...                        ...                             ...
# 31014                      NaN                             NaN
# 31015                      NaN                             NaN
# 31016                     3.04                           270.0
# 31017                      NaN                             NaN
# 31018                      NaN                             NaN
#
#        lieusaint_Speed(m/s)  lieusaint_Direction (deg N)  \
# 0                       NaN                          NaN
# 1                      1.50                        223.0
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# ...                     ...                          ...
# 31014                   NaN                          NaN
# 31015                   NaN                          NaN
# 31016                  3.12                        269.0
# 31017                   NaN                          NaN
# 31018                   NaN                          NaN
#
#        lvs-pussay_Speed(m/s)  lvs-pussay_Direction (deg N)  ...  \
# 0                        NaN                           NaN  ...
# 1                       1.71                         222.0  ...
# 2                        NaN                           NaN  ...
# 3                        NaN                           NaN  ...
# 4                        NaN                           NaN  ...
# ...                      ...                           ...  ...
# 31014                    NaN                           NaN  ...
# 31015                    NaN                           NaN  ...
# 31016                   2.44                         277.0  ...
# 31017                    NaN                           NaN  ...
# 31018                    NaN                           NaN  ...
#
#        parc-du-gatinais-b_Speed(m/s)  parc-du-gatinais-b_Direction (deg N)  \
# 0                                NaN                                   NaN
# 1                               2.51                                 225.0
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
# ...                              ...                                   ...
# 31014                            NaN                                   NaN
# 31015                            NaN                                   NaN
# 31016                           1.47                                 261.0
# 31017                            NaN                                   NaN
# 31018                            NaN                                   NaN
#
#        arville-b_Speed(m/s)  arville-b_Direction (deg N)  \
# 0                       NaN                          NaN
# 1                      2.52                        225.0
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# ...                     ...                          ...
# 31014                   NaN                          NaN
# 31015                   NaN                          NaN
# 31016                  1.53                        262.0
# 31017                   NaN                          NaN
# 31018                   NaN                          NaN
#
#        boissy-la-riviere-b_Speed(m/s)  boissy-la-riviere-b_Direction (deg N)  \
# 0                                 NaN                                    NaN
# 1                                2.73                                  226.0
# 2                                 NaN                                    NaN
# 3                                 NaN                                    NaN
# 4                                 NaN                                    NaN
# ...                               ...                                    ...
# 31014                             NaN                                    NaN
# 31015                             NaN                                    NaN
# 31016                            2.20                                  273.0
# 31017                             NaN                                    NaN
# 31018                             NaN                                    NaN
#
#        angerville-1-b_Speed(m/s)  angerville-1-b_Direction (deg N)  \
# 0                            NaN                               NaN
# 1                           2.74                             228.0
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
# ...                          ...                               ...
# 31014                        NaN                               NaN
# 31015                        NaN                               NaN
# 31016                       2.27                             275.0
# 31017                        NaN                               NaN
# 31018                        NaN                               NaN
#
#        angerville-2-b_Speed(m/s)  angerville-2-b_Direction (deg N)
# 0                            NaN                               NaN
# 1                           2.74                             228.0
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
# ...                          ...                               ...
# 31014                        NaN                               NaN
# 31015                        NaN                               NaN
# 31016                       2.27                             275.0
# 31017                        NaN                               NaN
# 31018                        NaN                               NaN
#
# [31019 rows x 36 columns]

# %%
merge_df = merge_df.fillna(method='ffill')

# %%
data = merge_df.copy()

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
#data['PJM_Load_MW_mean_halfday'] = data['PJM_Load_MW'].rolling(12).mean()
data['Wind_sum_mean_daily'] = data['Wind_sum'].rolling(24).mean()
data['Wind_sum_mean_weekly'] = data['Wind_sum'].rolling(24*7).mean()
data['Wind_sum_mean_monthly'] = data['Wind_sum'].rolling(24*30).mean()

# %%
data['Wind_sum_std_daily'] = data['Wind_sum'].rolling(24).std()
data['Wind_sum_std_weekly'] = data['Wind_sum'].rolling(24*7).std()
data['Wind_sum_std_monthly'] = data['Wind_sum'].rolling(24*30).std()

# %%
data['hour'] = data['datetime'].dt.hour
data['dayofweek'] = data['datetime'].dt.dayofweek
data['quarter'] = data['datetime'].dt.quarter
data['month'] = data['datetime'].dt.month
data['year'] = data['datetime'].dt.year 
data['dayofyear'] = data['datetime'].dt.dayofyear
data['dayofmonth'] = data['datetime'].dt.day
data['weekofyear'] = data['datetime'].dt.weekofyear

# %%
data['target'] = data['Wind_sum'].shift(-18)

# %%
data['Wind_std_lag'] = data['Wind_std'].shift(-18)
data['Wind_mean_lag'] = data['Wind_mean'].shift(-18)

# %%
data.dropna(axis=0, how='any', inplace=True)

# %%
mean_squared_error(y_true=data['target'],y_pred=data['Wind_sum'])
# Out:
# 24259508.43593554

# %%
mean_absolute_error(y_true=data['target'],y_pred=data['Wind_sum'])
# Out:
# 3558.5118882504457

# %%
mean_absolute_percentage_error(data['target'],data['Wind_sum'])
# Out:
# 76.14923881210825

# %%
data = data.drop(columns=['datetime','Wind_mean','Wind_sum','Wind_std'])

# %%
X_train = data[data.year.isin([2017,2018])].drop(columns=['target','year','month'])
X_test = data[data.year.isin([2019])].drop(columns=['target','year','month'])
y_train = data[data.year.isin([2017,2018])][['target']]
y_test = data[data.year.isin([2019])][['target']]

# %%
reg = xgb.XGBRegressor(n_estimators=100)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=True) # Change verbose to True if you want to see it train
# Out:
# [0]	validation_0-rmse:5332.42529	validation_1-rmse:6838.32129
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 50 rounds.
# [1]	validation_0-rmse:3739.61597	validation_1-rmse:4815.89551
# [2]	validation_0-rmse:2623.25342	validation_1-rmse:3394.34009
# [3]	validation_0-rmse:1841.20239	validation_1-rmse:2397.18359
# [4]	validation_0-rmse:1293.79224	validation_1-rmse:1699.72864
# [5]	validation_0-rmse:909.64154	validation_1-rmse:1209.59180
# [6]	validation_0-rmse:640.85266	validation_1-rmse:866.68872
# [7]	validation_0-rmse:452.39560	validation_1-rmse:628.25342
# [8]	validation_0-rmse:320.77539	validation_1-rmse:463.41208
# [9]	validation_0-rmse:228.41397	validation_1-rmse:349.72986
# [10]	validation_0-rmse:164.38217	validation_1-rmse:271.45593
# [11]	validation_0-rmse:119.56213	validation_1-rmse:220.08235
# [12]	validation_0-rmse:88.54371	validation_1-rmse:187.34695
# [13]	validation_0-rmse:67.81659	validation_1-rmse:164.64587
# [14]	validation_0-rmse:54.25609	validation_1-rmse:150.05785
# [15]	validation_0-rmse:46.23174	validation_1-rmse:140.85507
# [16]	validation_0-rmse:39.84781	validation_1-rmse:133.65143
# [17]	validation_0-rmse:36.07823	validation_1-rmse:128.53192
# [18]	validation_0-rmse:33.76726	validation_1-rmse:126.14535
# [19]	validation_0-rmse:32.40434	validation_1-rmse:122.85699
# [20]	validation_0-rmse:30.98918	validation_1-rmse:121.73110
# [21]	validation_0-rmse:30.24572	validation_1-rmse:119.38419
# [22]	validation_0-rmse:29.80816	validation_1-rmse:118.92133
# [23]	validation_0-rmse:28.92997	validation_1-rmse:118.56202
# [24]	validation_0-rmse:28.08763	validation_1-rmse:118.24864
# [25]	validation_0-rmse:27.71018	validation_1-rmse:116.34067
# [26]	validation_0-rmse:27.26227	validation_1-rmse:115.94209
# [27]	validation_0-rmse:26.82583	validation_1-rmse:114.21434
# [28]	validation_0-rmse:26.19183	validation_1-rmse:112.98265
# [29]	validation_0-rmse:25.96858	validation_1-rmse:111.59109
# [30]	validation_0-rmse:24.80775	validation_1-rmse:111.77404
# [31]	validation_0-rmse:24.50727	validation_1-rmse:110.79928
# [32]	validation_0-rmse:24.31276	validation_1-rmse:110.80067
# [33]	validation_0-rmse:23.99508	validation_1-rmse:110.69713
# [34]	validation_0-rmse:23.73288	validation_1-rmse:110.67292
# [35]	validation_0-rmse:23.65476	validation_1-rmse:109.84057
# [36]	validation_0-rmse:23.45488	validation_1-rmse:109.65309
# [37]	validation_0-rmse:23.02365	validation_1-rmse:109.67415
# [38]	validation_0-rmse:22.95264	validation_1-rmse:109.07630
# [39]	validation_0-rmse:22.80405	validation_1-rmse:109.06074
# [40]	validation_0-rmse:22.73495	validation_1-rmse:108.94866
# [41]	validation_0-rmse:22.45867	validation_1-rmse:108.90082
# [42]	validation_0-rmse:21.85598	validation_1-rmse:108.91443
# [43]	validation_0-rmse:21.37572	validation_1-rmse:108.88004
# [44]	validation_0-rmse:20.94233	validation_1-rmse:108.75835
# [45]	validation_0-rmse:20.43842	validation_1-rmse:108.86496
# [46]	validation_0-rmse:20.38459	validation_1-rmse:108.31293
# [47]	validation_0-rmse:20.26148	validation_1-rmse:108.21509
# [48]	validation_0-rmse:20.08604	validation_1-rmse:108.29005
# [49]	validation_0-rmse:19.94489	validation_1-rmse:108.27037
# [50]	validation_0-rmse:19.57601	validation_1-rmse:108.32686
# [51]	validation_0-rmse:19.38092	validation_1-rmse:108.29449
# [52]	validation_0-rmse:19.29822	validation_1-rmse:108.28547
# [53]	validation_0-rmse:19.23857	validation_1-rmse:108.27778
# [54]	validation_0-rmse:19.20169	validation_1-rmse:107.97797
# [55]	validation_0-rmse:19.13163	validation_1-rmse:107.96941
# [56]	validation_0-rmse:19.06951	validation_1-rmse:107.92790
# [57]	validation_0-rmse:18.92901	validation_1-rmse:107.92917
# [58]	validation_0-rmse:18.83016	validation_1-rmse:107.77404
# [59]	validation_0-rmse:18.54949	validation_1-rmse:107.72717
# [60]	validation_0-rmse:18.29710	validation_1-rmse:107.70689
# [61]	validation_0-rmse:18.27783	validation_1-rmse:107.53342
# [62]	validation_0-rmse:18.02243	validation_1-rmse:107.47308
# [63]	validation_0-rmse:18.00235	validation_1-rmse:107.40443
# [64]	validation_0-rmse:17.86706	validation_1-rmse:107.41105
# [65]	validation_0-rmse:17.66513	validation_1-rmse:107.36246
# [66]	validation_0-rmse:17.40818	validation_1-rmse:107.31853
# [67]	validation_0-rmse:17.06342	validation_1-rmse:107.24696
# [68]	validation_0-rmse:16.82889	validation_1-rmse:107.20624
# [69]	validation_0-rmse:16.70721	validation_1-rmse:107.17284
# [70]	validation_0-rmse:16.64580	validation_1-rmse:107.16694
# [71]	validation_0-rmse:16.48022	validation_1-rmse:107.13750
# [72]	validation_0-rmse:16.36861	validation_1-rmse:107.15919
# [73]	validation_0-rmse:16.34228	validation_1-rmse:107.14900
# [74]	validation_0-rmse:16.26681	validation_1-rmse:107.15063
# [75]	validation_0-rmse:15.95533	validation_1-rmse:107.05471
# [76]	validation_0-rmse:15.57714	validation_1-rmse:106.99120
# [77]	validation_0-rmse:15.38178	validation_1-rmse:106.95092
# [78]	validation_0-rmse:15.31572	validation_1-rmse:106.91532
# [79]	validation_0-rmse:15.26280	validation_1-rmse:106.90965
# [80]	validation_0-rmse:15.22545	validation_1-rmse:106.77304
# [81]	validation_0-rmse:15.06433	validation_1-rmse:106.74096
# [82]	validation_0-rmse:15.03435	validation_1-rmse:106.74163
# [83]	validation_0-rmse:14.97633	validation_1-rmse:106.73635
# [84]	validation_0-rmse:14.86588	validation_1-rmse:106.72673
# [85]	validation_0-rmse:14.77148	validation_1-rmse:106.76043
# [86]	validation_0-rmse:14.67564	validation_1-rmse:106.74495
# [87]	validation_0-rmse:14.57812	validation_1-rmse:106.74663
# [88]	validation_0-rmse:14.53524	validation_1-rmse:106.74264
# [89]	validation_0-rmse:14.43463	validation_1-rmse:106.74420
# [90]	validation_0-rmse:14.38190	validation_1-rmse:106.74397
# [91]	validation_0-rmse:14.32253	validation_1-rmse:106.64130
# [92]	validation_0-rmse:14.29822	validation_1-rmse:106.37019
# [93]	validation_0-rmse:14.19988	validation_1-rmse:106.36218
# [94]	validation_0-rmse:14.18394	validation_1-rmse:106.35950
# [95]	validation_0-rmse:14.11843	validation_1-rmse:106.37185
# [96]	validation_0-rmse:14.06684	validation_1-rmse:106.38239
# [97]	validation_0-rmse:14.00498	validation_1-rmse:106.39333
# [98]	validation_0-rmse:13.90589	validation_1-rmse:106.37871
# [99]	validation_0-rmse:13.89468	validation_1-rmse:106.38110
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
pyplot.rcParams["figure.figsize"] = (20,10)

# %%
# retrieve performance metrics
results = reg.evals_result()
epochs = len(results['validation_0']['rmse'])
x_axis = range(0, epochs)
# plot rmse
fig, ax = pyplot.subplots()
ax.plot(x_axis, results['validation_0']['rmse'], label='Train')
ax.plot(x_axis, results['validation_1']['rmse'], label='Test')
ax.legend()
pyplot.ylabel('RMSE')
pyplot.title('XGBoost RMSE')
pyplot.show()

# %%
_ = plot_importance(reg, height=0.9)

# %%
mean_squared_error(y_true=y_test,y_pred=reg.predict(X_test))
# Out:
# 11312.34822981581

# %%
mean_absolute_error(y_true=y_test,y_pred=reg.predict(X_test))
# Out:
# 24.826631580857924

# %%
mean_absolute_percentage_error(y_test,reg.predict(X_test))
# Out:
# 155.46781785405773

# %%
test_result = data[data.year.isin([2019])].copy()
test_result['prediction'] = reg.predict(X_test)

# %%
test_result['error'] = test_result['target'] - test_result['prediction']
test_result['abs_error'] = test_result['error'].apply(np.abs)
error_by_day = test_result.groupby(['year','month','dayofmonth']) \
    .mean()[['target','prediction','error','abs_error']]

# %%
test_result.sort_values('abs_error', ascending=False)
# Out:
#                  datetime  Wind_mean  Wind_sum    Wind_std  \
# 19640 2019-03-30 07:00:00     2490.5    4981.0  245.366053
# 19639 2019-03-30 06:00:00     2847.0    5694.0    9.899495
# 25819 2019-12-12 18:00:00    11218.0   22436.0  104.651804
# 21771 2019-06-27 01:00:00     5399.0   10798.0   31.112698
# 19245 2019-03-13 20:00:00    10502.0   21004.0   82.024387
# ...                   ...        ...       ...         ...
# 23078 2019-08-20 12:00:00     1418.5    2837.0  118.086832
# 21151 2019-06-01 05:00:00      988.0    1976.0   24.041631
# 19992 2019-04-13 22:00:00     3310.5    6621.0  106.773124
# 20820 2019-05-18 10:00:00      792.5    1585.0   38.890873
# 22266 2019-07-17 16:00:00     1557.0    3114.0  127.279221
#
#        guitrancourt_Speed(m/s)  guitrancourt_Direction (deg N)  \
# 19640                     2.09                           180.0
# 19639                     2.09                           180.0
# 25819                     7.01                           168.0
# 21771                     5.80                            41.0
# 19245                     6.71                           279.0
# ...                        ...                             ...
# 23078                     3.71                           278.0
# 21151                     1.20                           161.0
# 19992                     3.44                            29.0
# 20820                     2.05                            57.0
# 22266                     2.59                           260.0
#
#        lieusaint_Speed(m/s)  lieusaint_Direction (deg N)  \
# 19640                  2.63                        185.0
# 19639                  2.63                        185.0
# 25819                  7.49                        168.0
# 21771                  4.81                         28.0
# 19245                  5.29                        280.0
# ...                     ...                          ...
# 23078                  1.97                        302.0
# 21151                  1.29                        151.0
# 19992                  3.23                         29.0
# 20820                  3.00                        166.0
# 22266                  2.22                        243.0
#
#        lvs-pussay_Speed(m/s)  lvs-pussay_Direction (deg N)  ...  year  \
# 19640                   2.87                         190.0  ...  2019
# 19639                   2.87                         190.0  ...  2019
# 25819                   6.82                         171.0  ...  2019
# 21771                   5.11                          41.0  ...  2019
# 19245                   5.16                         281.0  ...  2019
# ...                      ...                           ...  ...   ...
# 23078                   2.49                         303.0  ...  2019
# 21151                   1.08                         127.0  ...  2019
# 19992                   3.00                          39.0  ...  2019
# 20820                   2.73                         164.0  ...  2019
# 22266                   3.47                         268.0  ...  2019
#
#        dayofyear  dayofmonth  weekofyear   target  Wind_std_lag  \
# 19640         89          30          13   4437.0     10.404326
# 19639         89          30          13   4437.0     10.404326
# 25819        346          12          50  26647.0      6.363961
# 21771        178          27          26   9750.0    213.546248
# 19245         72          13          11  26553.0     13.435029
# ...          ...         ...         ...      ...           ...
# 23078        232          20          34   3440.0    125.865007
# 21151        152           1          22   3788.0    101.823376
# 19992        103          13          15   5279.0    101.116270
# 20820        138          18          20   2061.0     45.961941
# 22266        198          17          29   4321.0    184.554870
#
#        Wind_mean_lag    prediction        error    abs_error
# 19640        1109.25   2214.943848  2222.056152  2222.056152
# 19639        1109.25   2214.943848  2222.056152  2222.056152
# 25819       13323.50  24447.392578  2199.607422  2199.607422
# 21771        4875.00  11942.224609 -2192.224609  2192.224609
# 19245       13276.50  24452.962891  2100.037109  2100.037109
# ...              ...           ...          ...          ...
# 23078        1720.00   3439.988770     0.011230     0.011230
# 21151        1894.00   3788.003906    -0.003906     0.003906
# 19992        2639.50   5278.997070     0.002930     0.002930
# 20820        1030.50   2061.000244    -0.000244     0.000244
# 22266        2160.50   4321.000000     0.000000     0.000000
#
# [8760 rows x 56 columns]

# %%
# Over forecasted days
error_by_day.sort_values('error', ascending=True).head(20)
# Out:
#                              target    prediction      error   abs_error
# year month dayofmonth
# 2019 6     27           6727.416667   6819.972656 -92.555837  105.266388
#      4     27          10368.125000  10424.918945 -56.793538   83.076457
#      10    10          11037.916667  11090.205078 -52.288249   70.150716
#      3     17           8734.833333   8781.118164 -46.284993   54.848755
#            8           18365.333333  18407.914062 -42.580688   60.348104
#      4     1            7782.333333   7821.664062 -39.330790   40.486715
#            4            6578.041667   6612.980469 -34.938965   34.938965
#            2            5404.333333   5436.698242 -32.364807   32.364807
#            3            4600.166667   4629.881348 -29.714864   30.036764
#      12    16          15063.625000  15092.651367 -29.026082   31.058634
#      2     12           3318.541667   3342.271240 -23.729691   40.584590
#            8           20699.708333  20721.716797 -22.008830   58.042114
#      10    25          13253.583333  13275.421875 -21.838745   29.637004
#      3     5           17984.166667  18005.972656 -21.805684   23.451436
#      12    15           9129.041667   9148.927734 -19.885986   23.613200
#            28           5034.666667   5053.367188 -18.700521   19.509155
#      9     28          18338.291667  18356.744141 -18.453328   47.537069
#      3     27           5254.000000   5272.418945 -18.418894   19.623667
#      4     9            4957.875000   4975.452637 -17.577464   18.481089
#      12    25           9007.041667   9024.567383 -17.526194   19.475739

# %%
_ = test_result[['target','prediction']].plot(figsize=(15, 5))
